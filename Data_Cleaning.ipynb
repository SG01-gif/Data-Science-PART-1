# %% [markdown]
#  Raw Data Problems : --> 1. Missing vals , 2. Duplicate val , 3. Spelling Mistake , 4. Ouliers , 5. Incorrect datatypes , 6. Incorrect formatting

# %% [markdown]
# Data Cleaning :--> detecting , processing and handling missing values , outliers and duplicates

# %% [markdown]
# # Data Collection and Inspection (Summary,distribution plot,info,frequency,visual inspect)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', encoding='latin1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.isnull().sum()/len(df)*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# CustomerID has so much missing vals ..
# dont drop na

# %%
df[df.duplicated()].shape
# Out:
# (5268, 8)

# %%
df['CustomerID'].value_counts().head(10)
# Out:
# CustomerID
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
# 15311.0    2491
# 14646.0    2085
# 13089.0    1857
# 13263.0    1677
# 14298.0    1640
# Name: count, dtype: int64

# %%
df[df['CustomerID']==17841.0]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 1441     C536543     22632        HAND WARMER RED RETROSPOT        -1
# 1442     C536543     22355        CHARLOTTE BAG SUKI DESIGN        -2
# 2037      536557     21495       SKULLS AND CROSSBONES WRAP        25
# 2038      536557    46000R     POLYESTER FILLER PAD 45x30cm         2
# 2039      536557    46000S     POLYESTER FILLER PAD 40x40cm         1
# ...          ...       ...                              ...       ...
# 537749    581334     23399    HOME SWEET HOME HANGING HEART         3
# 537750    581334     22893   MINI CAKE STAND T-LIGHT HOLDER        12
# 537751    581334     22371     AIRLINE BAG VINTAGE TOKYO 78         1
# 537752    581334     22309             TEA COSY RED  STRIPE         1
# 537753    581334     21926  RED/CREAM STRIPE CUSHION COVER          8
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 1441    12/1/2010 14:30       2.10     17841.0  United Kingdom
# ...

# %%
for col in df.columns:
    if df[col].nunique() < 20:
        print(col)
        print(df[col].value_counts())
        print('-'*50)

# %% [markdown]
#  Handling the missing vals : 1.Delete Rows/Cols(when more than 50 % data missing).. , 2.Imputation (filling missing vals)--> mean , median , mode .. 3.Forward fill / Backward fill (Look forward data and backward data) ... 4. Predictive Imputation (using ml model )...

# %%
df.dropna(subset=['CustomerID'], inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# All Null values removes ..

# %% [markdown]
# Handling Duplicates .. 1 . Remove duplicate . 2 . Cheak primary key , 3 . Remove near duplicate records ..

# %%
df.drop_duplicates(inplace=True)

# %%
df['CustomerID'].value_counts()
# Out:
# CustomerID
# 17841.0    7812
# 14911.0    5898
# 14096.0    5128
# 12748.0    4459
# 14606.0    2759
#            ...
# 16093.0       1
# 15313.0       1
# 15753.0       1
# 15195.0       1
# 13747.0       1
# Name: count, Length: 4372, dtype: int64

# %%
df.drop_duplicates(subset=['CustomerID'],keep='first')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 46        536371     22086      PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65        536374     21258           VICTORIAN SEWING BOX LARGE        32
# ...          ...       ...                                  ...       ...
# 536969    581233     22178      VICTORIAN GLASS HANGING T-LIGHT         6
# 537255    581241     22922     FRIDGE MAGNETS US DINER ASSORTED        12
# 538064    581385    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        24
# 538812    581416     22466       FAIRY TALE COTTAGE NIGHT LIGHT         1
# 541768    581578      POST                              POSTAGE         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Correct the Datatypes .. 1. Neumeric --> Int / Float , 2. Categorical --> Object , 3. Date / Time --> datetime

# %% [markdown]
# Handling Outliers : 1. Genuine outliers , 2. Errors
